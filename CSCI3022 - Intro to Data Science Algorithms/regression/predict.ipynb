# %%
import pandas
from sklearn import linear_model, feature_extraction

# %%
def categorical_features(row):
    d = {}
    d["STATE"] = row[1]["STATE"]
    return d

def last_poll(full_data):
    """
    Create feature from last poll in each state
    """
    
    # Only care about republicans
    repub = full_data[full_data["PARTY"] == "Rep"]

    # Sort by date
    chron = repub.sort_values(by="DATE", ascending=True)

    # Only keep the last one
    dedupe = chron.drop_duplicates(subset="STATE", keep="last")

    # Remove national polls
    return dedupe[dedupe["STATE"] != "US"]

def npolls(full_data, n=None):
    """
    Create feature from last poll in each state
    """
    if n == None:
        n = 1
    
    # Only care about republicans
    repub = full_data[full_data["PARTY"] == "Rep"]

    # Sort by date
    chron = repub.sort_values(by="DATE", ascending=True).groupby(["STATE"]).tail(n)

    # Only keep the last one
    #dedupe = chron.drop_duplicates(subset="STATE", keep="last")
    dedupe = chron #2540.5644747797082

    # Remove national polls
    return dedupe[dedupe["STATE"] != "US"]

# %%
all_data = pandas.read_csv("data.csv")
all_data = all_data[pandas.notnull(all_data["STATE"])]
train_x = npolls(all_data[all_data["TOPIC"] == '2012-president'])
print(train_x)
# Out:
#       YEAR        DATE           TOPIC  \
# 23    2012  2011-02-22  2012-president
# 37    2012  2011-03-27  2012-president
# 119   2012  2011-07-10  2012-president
# 31    2012  2011-08-28  2012-president
# 756   2012  2011-10-02  2012-president
# 530   2012  2011-10-13  2012-president
# 482   2012  2011-10-14  2012-president
# 80    2012  2011-10-16  2012-president
# 45    2012  2011-11-06  2012-president
# 70    2012  2011-11-10  2012-president
# 578   2012  2011-11-21  2012-president
# 65    2012  2011-11-21  2012-president
# 531   2012  2011-12-06  2012-president
# 583   2012  2011-12-14  2012-president
# 545   2012  2012-01-13  2012-president
# 417   2012  2012-01-15  2012-president
# 1118  2012  2012-02-06  2012-president
# 414   2012  2012-02-15  2012-president
# 525   2012  2012-02-17  2012-president
# 466   2012  2012-02-22  2012-president
# 363   2012  2012-02-22  2012-president
# 479   2012  2012-02-25  2012-president
# 745   2012  2012-03-05  2012-president
# 577   2012  2012-03-19  2012-president
# 751   2012  2012-03-25  2012-president
# 1311  2012  2012-03-26  2012-president
# 412   2012  2012-04-22  2012-president
# 83    2012  2012-04-28  2012-president
# 455   2012  2012-05-09  2012-president
# 574   2012  2012-05-10  2012-president
# ...    ...         ...             ...
# 486   2012  2012-11-04  2012-president
# 1763  2012  2012-11-04  2012-president
# 1767  2012  2012-11-04  2012-president
# 1807  2012  2012-11-04  2012-president
# 1754  2012  2012-11-04  2012-president
# 2207  2012  2012-11-04  2012-president
# 1403  2012  2012-11-04  2012-president
# 1606  2012  2012-11-04  2012-president
# 2099  2012  2012-11-04  2012-president
# 2102  2012  2012-11-04  2012-president
# 1537  2012  2012-11-04  2012-president
# 1574  2012  2012-11-04  2012-president
# 1581  2012  2012-11-04  2012-president
# 1570  2012  2012-11-04  2012-president
# 1473  2012  2012-11-04  2012-president
# 1478  2012  2012-11-04  2012-president
# 2030  2012  2012-11-04  2012-president
# 1433  2012  2012-11-04  2012-president
# 2163  2012  2012-11-04  2012-president
# 2166  2012  2012-11-04  2012-president
# 1413  2012  2012-11-04  2012-president
# 1614  2012  2012-11-04  2012-president
# 2157  2012  2012-11-05  2012-president
# 2210  2012  2012-11-05  2012-president
# 1393  2012  2012-11-05  2012-president
# 2145  2012  2012-11-05  2012-president
# 2140  2012  2012-11-05  2012-president
# 1545  2012  2012-11-05  2012-president
# 1548  2012  2012-11-05  2012-president
# 1556  2012  2012-11-05  2012-president
#
#                                                  NAME   MOE  \
# 23      2012 Rhode Island President: Romney vs. Obama  4.20
# 37       2012 Mississippi President: Romney vs. Obama  3.40
# 119             2012 Utah President: Romney vs. Obama  3.60
# 31          2012 Kentucky President: Romney vs. Obama  4.00
# 756         2012 Nebraska President: Romney vs. Obama  3.60
# 530   2012 South Carolina President: Romney vs. Obama  2.10
# 482        2012 Tennessee President: Romney vs. Obama  4.00
# 80            2012 Hawaii President: Romney vs. Obama  4.10
# 45       2012 Mississippi President: Romney vs. Obama  3.50
# 70            2012 Kansas President: Romney vs. Obama  3.50
# 578           2012 Oregon President: Romney vs. Obama  4.40
# 65            2012 Kansas President: Romney vs. Obama  4.40
# 531   2012 South Carolina President: Romney vs. Obama  2.10
# 583           2012 Oregon President: Romney vs. Obama  3.10
# 545   2012 South Carolina President: Romney vs. Obama  3.40
# 417            2012 Texas President: Romney vs. Obama  3.70
# 1118        2012 Illinois President: Romney vs. Obama   NaN
# 414            2012 Texas President: Romney vs. Obama  4.30
# 525     2012 South Dakota President: Romney vs. Obama  4.20
# 466        2012 Tennessee President: Romney vs. Obama  3.00
# 363          2012 Vermont President: Romney vs. Obama   NaN
# 479        2012 Tennessee President: Romney vs. Obama  5.00
# 745         2012 Nebraska President: Romney vs. Obama  4.50
# 577           2012 Oregon President: Romney vs. Obama  2.50
# 751         2012 Nebraska President: Romney vs. Obama  3.10
# 1311        2012 Arkansas President: Romney vs. Obama  3.60
# 412            2012 Texas President: Romney vs. Obama  4.00
# 83     2012 West Virginia President: Romney vs. Obama  4.80
# 455        2012 Tennessee President: Romney vs. Obama  3.40
# 574           2012 Oregon President: Romney vs. Obama  2.60
# ...                                               ...   ...
# 486     2012 South Dakota President: Romney vs. Obama  3.95
# 1763   2012 New Hampshire President: Romney vs. Obama   NaN
# 1767   2012 New Hampshire President: Romney vs. Obama  2.50
# 1807          2012 Nevada President: Romney vs. Obama  3.60
# 1754   2012 New Hampshire President: Romney vs. Obama  4.00
# 2207        2012 Colorado President: Romney vs. Obama  4.00
# 1403        2012 Virginia President: Romney vs. Obama  3.50
# 1606  2012 North Carolina President: Romney vs. Obama  2.90
# 2099            2012 Iowa President: Romney vs. Obama  4.00
# 2102            2012 Iowa President: Romney vs. Obama  2.90
# 1537            2012 Ohio President: Romney vs. Obama  4.10
# 1574            2012 Ohio President: Romney vs. Obama  3.30
# 1581            2012 Ohio President: Romney vs. Obama  3.10
# 1570            2012 Ohio President: Romney vs. Obama  4.00
# 1473    2012 Pennsylvania President: Romney vs. Obama  3.00
# 1478    2012 Pennsylvania President: Romney vs. Obama   NaN
# 2030        2012 Michigan President: Romney vs. Obama  2.71
# 1433        2012 Virginia President: Romney vs. Obama  3.10
# 2163         2012 Florida President: Romney vs. Obama  4.60
# 2166         2012 Florida President: Romney vs. Obama  3.20
# 1413        2012 Virginia President: Romney vs. Obama  4.00
# 1614  2012 North Carolina President: Romney vs. Obama  3.20
# 2157         2012 Florida President: Romney vs. Obama  3.10
# 2210        2012 Colorado President: Romney vs. Obama   NaN
# 1393        2012 Virginia President: Romney vs. Obama   NaN
# 2145         2012 Florida President: Romney vs. Obama   NaN
# 2140         2012 Florida President: Romney vs. Obama  3.50
# 1545            2012 Ohio President: Romney vs. Obama  3.50
# 1548            2012 Ohio President: Romney vs. Obama   NaN
# 1556            2012 Ohio President: Romney vs. Obama  2.70
#
#                  SUBPOP  SUBPOPID  CHOICE PARTY  VALUE     OBS STATE
# 23        Likely Voters         1  Romney   Rep   37.0   544.0    RI
# 37        Likely Voters         1  Romney   Rep   46.0   817.0    MS
# 119       Likely Voters         1  Romney   Rep   63.0   732.0    UT
# 31        Likely Voters         1  Romney   Rep   48.0   600.0    KY
# 756       Likely Voters         1  Romney   Rep   51.0   739.0    NE
# 530       Likely Voters         1  Romney   Rep   46.0  2131.0    SC
# 482              Adults         1  Romney   Rep   44.0   640.0    TN
# 80        Likely Voters         1  Romney   Rep   32.0   568.0    HI
# 45        Likely Voters         1  Romney   Rep   54.0   796.0    MS
# 70        Likely Voters         1  Romney   Rep   56.0   800.0    KS
# 578       Likely Voters         1  Romney   Rep   40.0   528.0    OR
# 65    Registered Voters         1  Romney   Rep   48.0   510.0    KS
# 531       Likely Voters         1  Romney   Rep   42.0  2107.0    SC
# 583       Likely Voters         1  Romney   Rep   40.0   979.0    OR
# 545   Registered Voters         1  Romney   Rep   46.0   995.0    SC
# 417       Likely Voters         1  Romney   Rep   49.0   700.0    TX
# 1118  Registered Voters         1  Romney   Rep   35.0   600.0    IL
# 414       Likely Voters         1  Romney   Rep   49.0   529.0    TX
# 525   Registered Voters         1  Romney   Rep   44.0   559.0    SD
# 466   Registered Voters         1  Romney   Rep   42.0  1508.0    TN
# 363   Registered Voters         1  Romney   Rep   33.0   664.0    VT
# 479       Likely Voters         1  Romney   Rep   47.0   416.0    TN
# 745       Likely Voters         1  Romney   Rep   52.0   500.0    NE
# 577       Likely Voters         1  Romney   Rep   39.0  1615.0    OR
# 751       Likely Voters         1  Romney   Rep   51.0  1028.0    NE
# 1311      Likely Voters         1  Romney   Rep   57.0   759.0    AR
# 412       Likely Voters         1  Romney   Rep   50.0   591.0    TX
# 83        Likely Voters         1  Romney   Rep   54.0   410.0    WV
# 455   Registered Voters         1  Romney   Rep   47.0   826.0    TN
# 574   Registered Voters         1  Romney   Rep   43.0  1468.0    OR
# ...                 ...       ...     ...   ...    ...     ...   ...
# 486       Likely Voters         1  Romney   Rep   53.0   617.0    SD
# 1763      Likely Voters         1  Romney   Rep   46.0   776.0    NH
# 1767      Likely Voters         1  Romney   Rep   48.0  1550.0    NH
# 1807      Likely Voters         1  Romney   Rep   47.0   750.0    NV
# 1754      Likely Voters         1  Romney   Rep   49.0   600.0    NH
# 2207      Likely Voters         1  Romney   Rep   46.0   603.0    CO
# 1403      Likely Voters         1  Romney   Rep   44.0   814.0    VA
# 1606      Likely Voters         1  Romney   Rep   50.0  1130.0    NC
# 2099      Likely Voters         1  Romney   Rep   49.0   600.0    IA
# 2102      Likely Voters         1  Romney   Rep   48.0  1122.0    IA
# 1537      Likely Voters         1  Romney   Rep   48.0   572.0    OH
# 1574      Likely Voters         1  Romney   Rep   49.0   889.0    OH
# 1581      Likely Voters         1  Romney   Rep   47.0  1000.0    OH
# 1570      Likely Voters         1  Romney   Rep   49.0   750.0    OH
# 1473      Likely Voters         1  Romney   Rep   46.0  1060.0    PA
# 1478      Likely Voters         1  Romney   Rep   47.0   479.0    PA
# 2030      Likely Voters         1  Romney   Rep   46.0  1305.0    MI
# 1433      Likely Voters         1  Romney   Rep   47.0   975.0    VA
# 2163      Likely Voters         1  Romney   Rep   52.0   437.0    FL
# 2166      Likely Voters         1  Romney   Rep   49.0   955.0    FL
# 1413      Likely Voters         1  Romney   Rep   50.0   750.0    VA
# 1614      Likely Voters         1  Romney   Rep   49.0   926.0    NC
# 2157      Likely Voters         1  Romney   Rep   49.0  1060.0    FL
# 2210      Likely Voters         1  Romney   Rep   47.0   774.0    CO
# 1393      Likely Voters         1  Romney   Rep   46.0   828.0    VA
# 2145      Likely Voters         1  Romney   Rep   48.0   769.0    FL
# 2140      Likely Voters         1  Romney   Rep   48.0   876.0    FL
# 1545      Likely Voters         1  Romney   Rep   44.0   832.0    OH
# 1548      Likely Voters         1  Romney   Rep   46.0   680.0    OH
# 1556      Likely Voters         1  Romney   Rep   48.0  1316.0    OH
#
# [358 rows x 12 columns]

# %%
if __name__ == "__main__":
    # Read in the X data
    all_data = pandas.read_csv("data.csv")

    # Remove non-states
    all_data = all_data[pandas.notnull(all_data["STATE"])]

    # split between testing and training
    #train_x = npolls(all_data[all_data["TOPIC"] == '2012-president']) #2021.3667123442144
    #train_x = npolls(all_data[all_data["TOPIC"] == '2012-president'], 3) #2088.2307598216044
    #train_x = npolls(all_data[all_data["TOPIC"] == '2012-president'], 6) #2129.078770267785
    #train_x = npolls(all_data[all_data["TOPIC"] == '2012-president'], 9) #
    train_x = npolls(all_data[all_data["TOPIC"] == '2012-president'], 12) #
    train_x.set_index("STATE")
    
    test_x = last_poll(all_data[all_data["TOPIC"] == '2016-president'])
    test_x.set_index("STATE")
    
    # Read in the Y data
    y_data = pandas.read_csv("../data/2012_pres.csv", sep=';')
    y_data = y_data[y_data["PARTY"] == "R"]
    y_data = y_data[pandas.notnull(y_data["GENERAL %"])]
    y_data["GENERAL %"] = [float(x.replace(",", ".").replace("%", ""))
                           for x in y_data["GENERAL %"]]
    y_data["STATE"] = y_data["STATE ABBREVIATION"]
    y_data.set_index("STATE")

    backup = train_x
    train_x = y_data.merge(train_x, on="STATE",how='left')
    
    # make sure we have all states in the test data
    for ii in set(y_data.STATE) - set(test_x.STATE):
        new_row = pandas.DataFrame([{"STATE": ii}])
        test_x = test_x.append(new_row)

    # format the data for regression
    train_x = pandas.concat([train_x.STATE.astype(str).str.get_dummies(),
                             train_x], axis=1)
    test_x = pandas.concat([test_x.STATE.astype(str).str.get_dummies(),
                             test_x], axis=1)
        
    # handle missing data
    for dd in train_x, test_x:                
        dd["NOPOLL"] = pandas.isnull(dd["VALUE"])
        dd["VALUE"] = dd["VALUE"].fillna(0.0)
        
    # create feature list
    features = list(y_data.STATE)
    features.append("VALUE")
    features.append("NOPOLL")    
        
    # fit the regression
    #mod = linear_model.LinearRegression() #MSE = 2121.096713296368
    
    #mod = linear_model.Ridge(.5) #2113.8845100120075
    #mod = linear_model.Ridge(.8) #2112.848964277935     ***
    #mod = linear_model.Ridge(.2) #2116.8419143243755
    
    #mod = linear_model.Lasso(alpha=0.2) #2052.626114301892
    #mod = linear_model.Lasso(alpha=0.1) #2044.6961129089418   With 6 polls: 2017.6049243788343
    mod = linear_model.Lasso(alpha=0.3) #2072.707539293161   With 6 polls: 1897.0808958079351  With 9 polls: 1840.4118616586254  With 12 polls: 1824.9810324044872
    #mod = linear_model.Lasso(alpha=0.05) #2023.4943314517543 With 6 polls: 2011.2404532238545
    #mod = linear_model.Lasso(alpha=0.08) #2034.111415580015
    #mod = linear_model.Lasso(alpha=0.01) #2021.3667123442144     ***
        
    mod.fit(train_x[features], train_x["GENERAL %"])
    

    # Write out the model
    with open("model.txt", 'w') as out:
        out.write("BIAS\t%f\n" % mod.intercept_)
        for jj, kk in zip(features, mod.coef_):
            out.write("%s\t%f\n" % (jj, kk))
    
    # Write the predictions
    pred_test = mod.predict(test_x[features])
    with open("pred.txt", 'w') as out:
        for ss, vv in sorted(zip(list(test_x.STATE), pred_test)):
            out.write("%s\t%f\n" % (ss, vv))

# %%
model = open('model.txt', "r")
pred = open('pred.txt', "r")

STATES = ['AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']
modlst = []
predlst = []
for line in model:
    a,b = line.split()
    if(a in STATES):
        modlst.append(float(b))

for line in pred:
    a,b = line.split()
    if(a in STATES):
        predlst.append(float(b))

model.close()
pred.close()

print(sum((modlst[i]-predlst[i])**2 for i in range(0,50))/50)
# Out:
# 2365.090278921913
